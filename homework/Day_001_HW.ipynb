# %% [markdown]
# ## 作業1：
# [我選的資料](https://www.kaggle.com/c/favorita-grocery-sales-forecasting/data) 為厄瓜多爾Corporación Favorita零售商的商品單位銷售量預測
#
# #### 1. 你選的這組資料為何重要 ？
# 商品銷售量的預測不僅影響庫存管理，也可透過分析了解消費者的消費行為模式，良好的庫存管理可降低成本，了解消費者行為則可提供客製化的行銷活動提升銷售。
#
# #### 2. 資料從何而來 (tips: 譬如提供者是誰、以什麼方式蒐集)
# 提供者為CorporaciónFavorita零售商，主要提供的資料為每個分店的所有品項銷量紀錄，此競賽也納入了當地的每日油價資訊與節慶資訊等外部資料，作為銷量預測的參考
#
# #### 3. 蒐集而來的資料型態為何
# 皆為結構化資料
#
# #### 4. 這組資料想解決的問題如何評估
# 可透過分析找出影響各商品銷量的因素，例如時間、節慶、油價、分店地理位置等，以供各店於進貨時參考
# 也可利用分類與關聯性找出各店不同消費族群的偏好，以供各店進行銷售/行銷規劃

# %% [markdown]
# ## 作業2：
#
# 想像你經營一個自由載客車隊，你希望能透過數據分析以提升業績，請你思考並描述你如何規劃整體的分析/解決方案：
#
# #### 1. 核心問題為何 (tips：如何定義 「提升業績 & 你的假設」)
# 車隊司機需要在路上隨機尋找無事先預約的乘客>耗費時間與油錢>降低每天的載客周轉率
# 若能預測出乘客可能出沒的時間地點(經緯度)，就能提升載客周轉率並提升業績
#
# #### 2. 資料從何而來 (tips：哪些資料可能會對你想問的問題產生影響 & 資料如何蒐集)
# * 車隊GPS資訊，從每輛車的GPS裝置蒐集而來。
# * 地圖資訊，可透過Google API取得鄉鎮街道資料。
# * 載客紀錄，需建置內部載客系統來留存每趟乘車時間與起訖點
#
# #### 3. 蒐集而來的資料型態為何
# 皆為結構化資料，主要以字串與數字為主
#
# #### 4. 你要回答的問題，其如何評估 (tips：你的假設如何驗證)
# 回歸問題，預測乘客出現的時間地點與出現的機率，可利用MSE檢測預測準確度

# %% [markdown]
# ## 練習時間
# #### 請寫一個函式用來計算 Mean Square Error
# $ MSE = \frac{1}{n}\sum_{i=1}^{n}{(Y_i - \hat{Y}_i)^2} $
#
# ### Hint: [如何取平方](https://googoodesign.gitbooks.io/-ezpython/unit-1.html)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def mean_squared_error(y,y_hat):
    mse=np.mean((y-y_hat)**2)
    return mse

def mean_absolute_error(y, y_hat):
    mae=sum(abs(y - y_hat)) / len(y)
    return mae

# %%
w = 3
b = 0.5

x_lin = np.linspace(0, 100, 101)

y = (x_lin + np.random.randn(101) * 5) * w + b

plt.plot(x_lin, y, 'b.', label = 'data points')
plt.title("Assume we have data points")
plt.legend(loc = 2)
plt.show()

# %%
y_hat = x_lin * w + b
plt.plot(x_lin, y, 'b.', label = 'data')
plt.plot(x_lin, y_hat, 'r-', label = 'prediction')
plt.title("Assume we have data points (And the prediction)")
plt.legend(loc = 2)
plt.show()

# %%
# 執行 Function, 確認有沒有正常執行
MSE = mean_squared_error(y, y_hat)
MAE = mean_absolute_error(y, y_hat)
print("The Mean squared error is %.3f" % (MSE))
print("The Mean absolute error is %.3f" % (MAE))
# Out:
# The Mean squared error is 224.122
# The Mean absolute error is 11.694
